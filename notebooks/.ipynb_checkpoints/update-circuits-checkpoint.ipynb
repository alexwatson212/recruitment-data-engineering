# %% [markdown]
# # Update circuits
#
# This script searches for new circuits from the 'circuits.csv' file in the Minio object store. It compares them against circuits already listed in the database and inserts any new ones.
#
# #### ToDo:
# - Improve the matching logic, it is susceptible to false positives.
# - Quarantine records that may be incorrect.
# - Add a results reporting function.
# - Add additional metadata.
# - Make logic performance improvements.

# %%
import pandas as pd
from io import BytesIO
from minio import Minio
from sqlalchemy import create_engine, text
from fuzzywuzzy import fuzz

# %%
# Initialize Minio client
minio_client = Minio(
    "minio:9000",
    access_key="minioadmin",
    secret_key="minioadmin",
    secure=False
)

# Download the CSV file from the Minio bucket into a pandas DataFrame
data = minio_client.get_object("track.data-raw", "circuits.csv")
data = BytesIO(data.read())
df_csv = pd.read_csv(data)

# %%
df_csv
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# 2         Sakhir       Bahrain  26.03250   50.51060    7
# 3       Montmeló         Spain  41.57000    2.26111  109
# 4       Istanbul        Turkey  40.95170   29.40500  130
# ..           ...           ...       ...        ...  ...
# 72      Portimão      Portugal  37.22700   -8.62670  108
# 73       Mugello         Italy  43.99750   11.37190  255
# 74        Jeddah  Saudi Arabia  21.63190   39.10440   15
# 75     Al Daayen         Qatar  25.49000   51.45420   \N
# 76         Miami           USA  25.95810  -80.23890   \N
#
#                                                   url
# 0   http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1   http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2   http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3   http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          http://en.wikipedia.org/wiki/Istanbul_Park
# ..                                                ...
# 72  http://en.wikipedia.org/wiki/Algarve_Internati...
# 73       http://en.wikipedia.org/wiki/Mugello_Circuit
# 74  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
# 75  http://en.wikipedia.org/wiki/Losail_Internatio...
# 76  http://en.wikipedia.org/wiki/Miami_Internation...
#
# [77 rows x 9 columns]

# %%
# Initialize connection to the PostgreSQL database using SQLAlchemy
engine = create_engine('postgresql://admin:admin@pgdb/postgres')

# %%
# Query the database to get the current circuits
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)

# %%
df_db
# Out:
#     circuit_id circuit_reference  \
# 0            1          Montreal
# 1            2         Melbourne
# 2            3         Spielberg
# 3            4       Silverstone
# 4            5         Barcelona
# 5            6               Spa
# 6            7             Monza
# 7            8             Sochi
# 8            9       Nurburgring
# 9           10          Portimao
# 10          11           Mugello
# 11          12            Sakhir
# 12          13             Imola
# 13          14            Monaco
# 14          15              Baku
# 15          16       Paul Ricard
# 16          17       Hungaroring
# 17          18         Zandvoort
# 18          19             Hanoi
# 19          20            Austin
# 20          21            Mexico
# 21          22            Jeddah
# 22          23         Abu Dhabi
# 23          24         Las Vegas
# 24          25             Miami
#
#                                             name               location  \
# 0                      Circuit Gilles-Villeneuve               Montreal
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 2                                  Red Bull Ring              Spielberg
# 3                            Silverstone Circuit            Silverstone
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 6                      Autodromo Nazionale Monza                  Monza
# 7                                 Sochi Autodrom                  Sochi
# 8                                    Nürburgring                Nürburg
# 9             Autódromo Internacional do Algarve               Portimão
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 11                 Bahrain International Circuit                 Sakhir
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 13                             Circuit de Monaco            Monte Carlo
# 14                             Baku City Circuit                   Baku
# 15                           Circuit Paul Ricard           Le Castellet
# 16                                   Hungaroring               Mogyorod
# 17                             Circuit Zandvoort              Zandvoort
# 18                          Hanoi Street Circuit                  Hanoi
# 19                       Circuit of The Americas                 Austin
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 21                         Jeddah Street Circuit                 Jeddah
# 22                            Yas Marina Circuit              Abu Dhabi
# 23                      Las Vegas Street Circuit              Las Vegas
# 24                 Miami International Autodrome                  Miami
#
#         lat      lng
# 0   45.5060  -73.525
# 1  -37.8497  144.968
# 2   47.2230   14.761
# 3   52.0720   -1.017
# 4   41.5690    2.261
# 5   50.4360    5.971
# 6   45.6210    9.290
# 7   43.4070   39.960
# 8   50.3340    6.943
# 9   37.2320   -8.628
# 10  43.9980   11.372
# 11  26.0310   50.512
# 12  44.3430   11.716
# 13  43.7350    7.421
# 14  40.3720   49.853
# 15  43.2510    5.793
# 16  47.5810   19.250
# 17  52.3890    4.541
# 18  21.0210  105.843
# 19  30.1330  -97.641
# 20  19.4060  -99.090
# 21  21.5270   39.187
# 22  24.4700   54.603
# 23  36.1690 -115.136
# 24  25.7780  -80.202

# %%
# Define a threshold for the fuzz.ratio. This depends on how strict you want your matching to be.
threshold = 90

# %%
#increased the matching to 90 to create less false positives

# %%
for index, row in df_csv.iterrows():
    csv_circuit_name = row['name']
    csv_circuit = row[['circuitId', 'circuitRef', 'name', 'location', 'lat', 'lng']]
    match_found = False

    for _, db_row in df_db.iterrows():
        db_circuit_name = db_row['name']

        # Compare the circuit names using fuzzy matching
        if fuzz.ratio(csv_circuit_name.lower(), db_circuit_name.lower()) > threshold:
            match_found = True
            break

    # If no match is found, upsert the circuit into the database
    if not match_found:
        # The values need to be adapted according to the columns in your table
        insert_query = text("""
        INSERT INTO race_data.circuits 
        (circuit_reference, name, location, lat, lng) 
        VALUES (:circuitRef, :name, :location, :lat, :lng)
        """)
        csv_circuit_dict = csv_circuit.to_dict()
        del csv_circuit_dict['circuitId']  # remove 'circuitId' from the dict if it exists
        with engine.begin() as connection:
            connection.execute(insert_query, csv_circuit_dict)

# %%
# Show the final ressult for circuits:
# Query the database to get the current circuits
df_db = pd.read_sql("SELECT * FROM race_data.circuits", engine)

# Set max rows displayed in output to None
pd.set_option('display.max_rows', None)

# Display the DataFrame
df_db
# Out:
#     circuit_id circuit_reference  \
# 22          23         Abu Dhabi
# 43          44          adelaide
# 81          82            losail
# 58          59        anderstorp
# 19          20            Austin
# 14          15              Baku
# 60          61          montjuic
# 78          79         pedralbes
# 72          73              avus
# 77          78        bremgarten
# 61          62          nivelles
# 39          40            galvez
# 71          72         riverside
# 55          56        long_beach
# 75          76          ain-diab
# 45          46         donington
# 62          63           charade
# 54          55            dallas
# 49          50           detroit
# 53          54             dijon
# 67          68            george
# 41          42           estoril
# 74          75           sebring
# 18          19             Hanoi
# 52          53            zolder
# 29          30    hockenheimring
# 36          37             imola
# 12          13             Imola
# 35          36      indianapolis
# 27          28          istanbul
# 21          22            Jeddah
# 80          81            jeddah
# 40          41             jerez
# 50          51      brands_hatch
# 26          27            sepang
# 38          39             vegas
# 23          24         Las Vegas
# 15          16       Paul Ricard
# 65          66            lemans
# 73          74          monsanto
# 69          70           aintree
# 56          57            jarama
# 28          29       magny_cours
# 31          32        marina_bay
# 1            2         Melbourne
# 25          26       albert_park
# 20          21            Mexico
# 24          25             Miami
# 44          45           kyalami
# 16          17       Hungaroring
# 13          14            Monaco
# 4            5         Barcelona
# 0            1          Montreal
# 6            7             Monza
# 57          58      watkins_glen
# 8            9       Nurburgring
# 42          43           okayama
# 59          60           mosport
# 70          71          boavista
# 32          33              fuji
# 76          77           pescara
# 46          47           phoenix
# 9           10          Portimao
# 63          64         tremblant
# 66          67             reims
# 48          49       jacarepagua
# 64          65           essarts
# 11          12            Sakhir
# 10          11           Mugello
# 33          34          shanghai
# 3            4       Silverstone
# 7            8             Sochi
# 5            6               Spa
# 2            3         Spielberg
# 68          69           zeltweg
# 37          38            suzuka
# 34          35        interlagos
# 79          80             buddh
# 30          31          valencia
# 47          48           yeongam
# 17          18         Zandvoort
# 51          52         zandvoort
#
#                                             name               location  \
# 22                            Yas Marina Circuit              Abu Dhabi
# 43                       Adelaide Street Circuit               Adelaide
# 81                  Losail International Circuit              Al Daayen
# 58                          Scandinavian Raceway             Anderstorp
# 19                       Circuit of The Americas                 Austin
# 14                             Baku City Circuit                   Baku
# 60                                      Montjuïc              Barcelona
# 78                          Circuit de Pedralbes              Barcelona
# 72                                          AVUS                 Berlin
# 77                            Circuit Bremgarten                   Bern
# 61                              Nivelles-Baulers               Brussels
# 39                 Autódromo Juan y Oscar Gálvez           Buenos Aires
# 71               Riverside International Raceway             California
# 55                                    Long Beach             California
# 75                                      Ain Diab             Casablanca
# 45                                Donington Park       Castle Donington
# 62                               Charade Circuit       Clermont-Ferrand
# 54                                     Fair Park                 Dallas
# 49                        Detroit Street Circuit                Detroit
# 53                                 Dijon-Prenois                  Dijon
# 67                         Prince George Circuit  Eastern Cape Province
# 41                          Autódromo do Estoril                Estoril
# 74                 Sebring International Raceway                Florida
# 18                          Hanoi Street Circuit                  Hanoi
# 52                                        Zolder         Heusden-Zolder
# 29                                Hockenheimring             Hockenheim
# 36                 Autodromo Enzo e Dino Ferrari                  Imola
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 35                   Indianapolis Motor Speedway           Indianapolis
# 27                                 Istanbul Park               Istanbul
# 21                         Jeddah Street Circuit                 Jeddah
# 80                       Jeddah Corniche Circuit                 Jeddah
# 40                             Circuito de Jerez   Jerez de la Frontera
# 50                                  Brands Hatch                   Kent
# 26                  Sepang International Circuit           Kuala Lumpur
# 38                Las Vegas Strip Street Circuit              Las Vegas
# 23                      Las Vegas Street Circuit              Las Vegas
# 15                           Circuit Paul Ricard           Le Castellet
# 65                                       Le Mans                Le Mans
# 73                         Monsanto Park Circuit                 Lisbon
# 69                                       Aintree              Liverpool
# 56                                        Jarama                 Madrid
# 28                 Circuit de Nevers Magny-Cours            Magny Cours
# 31                     Marina Bay Street Circuit             Marina Bay
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 25                Albert Park Grand Prix Circuit              Melbourne
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 24                 Miami International Autodrome                  Miami
# 44                                       Kyalami                Midrand
# 16                                   Hungaroring               Mogyorod
# 13                             Circuit de Monaco            Monte Carlo
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 0                      Circuit Gilles-Villeneuve               Montreal
# 6                      Autodromo Nazionale Monza                  Monza
# 57                                  Watkins Glen         New York State
# 8                                    Nürburgring                Nürburg
# 42                 Okayama International Circuit                Okayama
# 59                 Mosport International Raceway                Ontario
# 70                          Circuito da Boavista                 Oporto
# 32                                 Fuji Speedway                  Oyama
# 76                               Pescara Circuit                Pescara
# 46                        Phoenix street circuit                Phoenix
# 9             Autódromo Internacional do Algarve               Portimão
# 63                        Circuit Mont-Tremblant                 Quebec
# 66                                   Reims-Gueux                  Reims
# 48         Autódromo Internacional Nelson Piquet         Rio de Janeiro
# 64                             Rouen-Les-Essarts                  Rouen
# 11                 Bahrain International Circuit                 Sakhir
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 33                Shanghai International Circuit               Shanghai
# 3                            Silverstone Circuit            Silverstone
# 7                                 Sochi Autodrom                  Sochi
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 2                                  Red Bull Ring              Spielberg
# 68                                       Zeltweg                 Styria
# 37                                Suzuka Circuit                 Suzuka
# 34                    Autódromo José Carlos Pace              São Paulo
# 79                   Buddh International Circuit          Uttar Pradesh
# 30                       Valencia Street Circuit               Valencia
# 47                  Korean International Circuit         Yeongam County
# 17                             Circuit Zandvoort              Zandvoort
# 51                        Circuit Park Zandvoort              Zandvoort
#
#          lat         lng
# 22  24.47000   54.603000
# 43 -34.92720  138.617000
# 81  25.49000   51.454200
# 58  57.26530   13.604200
# 19  30.13300  -97.641000
# 14  40.37200   49.853000
# 60  41.36640    2.151670
# 78  41.39030    2.116670
# 72  52.48060   13.251400
# 77  46.95890    7.401940
# 61  50.62110    4.326940
# 39 -34.69430  -58.459300
# 71  33.93700 -117.273000
# 55  33.76510 -118.189000
# 75  33.57860   -7.687500
# 45  52.83060   -1.375280
# 62  45.74720    3.038890
# 54  32.77740  -96.758700
# 49  42.32980  -83.040100
# 53  47.36250    4.899130
# 67 -33.04860   27.873600
# 41  38.75060   -9.394170
# 74  27.45470  -81.348300
# 18  21.02100  105.843000
# 52  50.98940    5.256940
# 29  49.32780    8.565830
# 36  44.34390   11.716700
# 12  44.34300   11.716000
# 35  39.79500  -86.234700
# 27  40.95170   29.405000
# 21  21.52700   39.187000
# 80  21.63190   39.104400
# 40  36.70830   -6.034170
# 50  51.35690    0.263056
# 26   2.76083  101.738000
# 38  36.11470 -115.173000
# 23  36.16900 -115.136000
# 15  43.25100    5.793000
# 65  47.95000    0.224231
# 73  38.71970   -9.203060
# 69  53.47690   -2.940560
# 56  40.61710   -3.585580
# 28  46.86420    3.163610
# 31   1.29140  103.864000
# 1  -37.84970  144.968000
# 25 -37.84970  144.968000
# 20  19.40600  -99.090000
# 24  25.77800  -80.202000
# 44 -25.98940   28.076700
# 16  47.58100   19.250000
# 13  43.73500    7.421000
# 4   41.56900    2.261000
# 0   45.50600  -73.525000
# 6   45.62100    9.290000
# 57  42.33690  -76.927200
# 8   50.33400    6.943000
# 42  34.91500  134.221000
# 59  44.04810  -78.675600
# 70  41.17050   -8.673250
# 32  35.37170  138.927000
# 76  42.47500   14.150800
# 46  33.44790 -112.075000
# 9   37.23200   -8.628000
# 63  46.18770  -74.609900
# 66  49.25420    3.930830
# 48 -22.97560  -43.395000
# 64  49.33060    1.004580
# 11  26.03100   50.512000
# 10  43.99800   11.372000
# 33  31.33890  121.220000
# 3   52.07200   -1.017000
# 7   43.40700   39.960000
# 5   50.43600    5.971000
# 2   47.22300   14.761000
# 68  47.20390   14.747800
# 37  34.84310  136.541000
# 34 -23.70360  -46.699700
# 79  28.34870   77.533100
# 30  39.45890   -0.331667
# 47  34.73330  126.417000
# 17  52.38900    4.541000
# 51  52.38880    4.540920

# %%
## Check for false positives

# %%
#increased the matching to 90 for all three categories so that if circuit reference and location 1 and 2 were different they
#would not be picked up
#there seems to be only three false positives after making this change

# %%
# Define the last_index variable to track the last index used in the DataFrame
last_index = 0

# Define an empty DataFrame
duplicates = pd.DataFrame(columns=['index1', 'index2', 'circuit_reference1', 'circuit_reference2', 'name1', 'name2', 'location1', 'location2', 'score'])

for i in range(len(df_db)):
    for j in range(i+1, len(df_db)):
        circuit_reference1 = df_db.iloc[i]['circuit_reference']
        circuit_reference2 = df_db.iloc[j]['circuit_reference']
        name1 = df_db.iloc[i]['name']
        name2 = df_db.iloc[j]['name']
        location1 = df_db.iloc[i]['location']
        location2 = df_db.iloc[j]['location']
        
        # Calculate the fuzzy match score for circuit_reference, name and location fields
        circuit_reference_score = fuzz.ratio(circuit_reference1.lower(), circuit_reference2.lower())
        name_score = fuzz.ratio(name1.lower(), name2.lower())
        location_score = fuzz.ratio(location1.lower(), location2.lower())
        
        # If the score is above a threshold (e.g. 80) for circuit_reference, name or location, consider them as potential duplicates
        if circuit_reference_score > 90 or name_score > 90 or location_score > 90:
            duplicates.loc[last_index] = {
                'index1': df_db.iloc[i]['circuit_id'],
                'index2': df_db.iloc[j]['circuit_id'],
                'circuit_reference1': circuit_reference1,
                'circuit_reference2': circuit_reference2,
                'name1': name1,
                'name2': name2,
                'location1': location1,
                'location2': location2,
                'score': max(circuit_reference_score, name_score, location_score)
            }
            last_index += 1

# Show the potential duplicates
duplicates
# Out:
#    index1  index2 circuit_reference1 circuit_reference2  \
# 0       2      26          Melbourne        albert_park
# 1      13      37              Imola              imola
# 2      18      52          Zandvoort          zandvoort
# 3      22      81             Jeddah             jeddah
# 4      24      39          Las Vegas              vegas
# 5      56      72         long_beach          riverside
# 6      61      79           montjuic          pedralbes
#
#                                           name1  \
# 0                  Melbourne Grand Prix Circuit
# 1  Autodromo Internazionale Enzo e Dino Ferrari
# 2                             Circuit Zandvoort
# 3                         Jeddah Street Circuit
# 4                      Las Vegas Street Circuit
# 5                                    Long Beach
# 6                                      Montjuïc
#
#                              name2   location1   location2  score
# 0   Albert Park Grand Prix Circuit   Melbourne   Melbourne    100
# 1    Autodromo Enzo e Dino Ferrari       Imola       Imola    100
# 2           Circuit Park Zandvoort   Zandvoort   Zandvoort    100
# 3          Jeddah Corniche Circuit      Jeddah      Jeddah    100
# 4   Las Vegas Strip Street Circuit   Las Vegas   Las Vegas    100
# 5  Riverside International Raceway  California  California    100
# 6             Circuit de Pedralbes   Barcelona   Barcelona    100

# %%
quarentinedRecords = duplicates[duplicates['index1'] != 2 ]

# %%
quarentinedRecords = quarentinedRecords[quarentinedRecords['index1'] != 56 ]

# %%
quarentinedRecords = quarentinedRecords[quarentinedRecords['index1'] != 61 ]

# %%
quarentinedRecords
# Out:
#    index1  index2 circuit_reference1 circuit_reference2  \
# 1      13      37              Imola              imola
# 2      18      52          Zandvoort          zandvoort
# 3      22      81             Jeddah             jeddah
# 4      24      39          Las Vegas              vegas
#
#                                           name1  \
# 1  Autodromo Internazionale Enzo e Dino Ferrari
# 2                             Circuit Zandvoort
# 3                         Jeddah Street Circuit
# 4                      Las Vegas Street Circuit
#
#                             name2  location1  location2  score
# 1   Autodromo Enzo e Dino Ferrari      Imola      Imola    100
# 2          Circuit Park Zandvoort  Zandvoort  Zandvoort    100
# 3         Jeddah Corniche Circuit     Jeddah     Jeddah    100
# 4  Las Vegas Strip Street Circuit  Las Vegas  Las Vegas    100

# %%
#Using index two we will remove duplicate tracks from the dataset to create results

# %%
qList = quarentinedRecords['index2']

# %%
qList
# Out:
# 1    37
# 2    52
# 3    81
# 4    39
# Name: index2, dtype: int64

# %%
#Drop rows round in qList

# %%
results = df_db.loc[~(df_db['circuit_id'] == 37) | (df_db['circuit_id'] == 52) | (df_db['circuit_id'] == 81) | (df_db['circuit_id'] == 39)]

# %%
#Show Results

# %%
results
# Out:
#     circuit_id circuit_reference  \
# 0            1          Montreal
# 1            2         Melbourne
# 2            3         Spielberg
# 3            4       Silverstone
# 4            5         Barcelona
# 5            6               Spa
# 6            7             Monza
# 7            8             Sochi
# 8            9       Nurburgring
# 9           10          Portimao
# 10          11           Mugello
# 11          12            Sakhir
# 12          13             Imola
# 13          14            Monaco
# 14          15              Baku
# 15          16       Paul Ricard
# 16          17       Hungaroring
# 17          18         Zandvoort
# 18          19             Hanoi
# 19          20            Austin
# 20          21            Mexico
# 21          22            Jeddah
# 22          23         Abu Dhabi
# 23          24         Las Vegas
# 24          25             Miami
# 25          26       albert_park
# 26          27            sepang
# 27          28          istanbul
# 28          29       magny_cours
# 29          30    hockenheimring
# 30          31          valencia
# 31          32        marina_bay
# 32          33              fuji
# 33          34          shanghai
# 34          35        interlagos
# 35          36      indianapolis
# 37          38            suzuka
# 38          39             vegas
# 39          40            galvez
# 40          41             jerez
# 41          42           estoril
# 42          43           okayama
# 43          44          adelaide
# 44          45           kyalami
# 45          46         donington
# 46          47           phoenix
# 47          48           yeongam
# 48          49       jacarepagua
# 49          50           detroit
# 50          51      brands_hatch
# 51          52         zandvoort
# 52          53            zolder
# 53          54             dijon
# 54          55            dallas
# 55          56        long_beach
# 56          57            jarama
# 57          58      watkins_glen
# 58          59        anderstorp
# 59          60           mosport
# 60          61          montjuic
# 61          62          nivelles
# 62          63           charade
# 63          64         tremblant
# 64          65           essarts
# 65          66            lemans
# 66          67             reims
# 67          68            george
# 68          69           zeltweg
# 69          70           aintree
# 70          71          boavista
# 71          72         riverside
# 72          73              avus
# 73          74          monsanto
# 74          75           sebring
# 75          76          ain-diab
# 76          77           pescara
# 77          78        bremgarten
# 78          79         pedralbes
# 79          80             buddh
# 80          81            jeddah
# 81          82            losail
#
#                                             name               location  \
# 0                      Circuit Gilles-Villeneuve               Montreal
# 1                   Melbourne Grand Prix Circuit              Melbourne
# 2                                  Red Bull Ring              Spielberg
# 3                            Silverstone Circuit            Silverstone
# 4                 Circuit de Barcelona-Catalunya               Montmelo
# 5                   Circuit de Spa-Francorchamps      Spa Francorchamps
# 6                      Autodromo Nazionale Monza                  Monza
# 7                                 Sochi Autodrom                  Sochi
# 8                                    Nürburgring                Nürburg
# 9             Autódromo Internacional do Algarve               Portimão
# 10          Autodromo Internazionale del Mugello  Scarperia e San Piero
# 11                 Bahrain International Circuit                 Sakhir
# 12  Autodromo Internazionale Enzo e Dino Ferrari                  Imola
# 13                             Circuit de Monaco            Monte Carlo
# 14                             Baku City Circuit                   Baku
# 15                           Circuit Paul Ricard           Le Castellet
# 16                                   Hungaroring               Mogyorod
# 17                             Circuit Zandvoort              Zandvoort
# 18                          Hanoi Street Circuit                  Hanoi
# 19                       Circuit of The Americas                 Austin
# 20                  Autódromo Hermanos Rodríguez            Mexico City
# 21                         Jeddah Street Circuit                 Jeddah
# 22                            Yas Marina Circuit              Abu Dhabi
# 23                      Las Vegas Street Circuit              Las Vegas
# 24                 Miami International Autodrome                  Miami
# 25                Albert Park Grand Prix Circuit              Melbourne
# 26                  Sepang International Circuit           Kuala Lumpur
# 27                                 Istanbul Park               Istanbul
# 28                 Circuit de Nevers Magny-Cours            Magny Cours
# 29                                Hockenheimring             Hockenheim
# 30                       Valencia Street Circuit               Valencia
# 31                     Marina Bay Street Circuit             Marina Bay
# 32                                 Fuji Speedway                  Oyama
# 33                Shanghai International Circuit               Shanghai
# 34                    Autódromo José Carlos Pace              São Paulo
# 35                   Indianapolis Motor Speedway           Indianapolis
# 37                                Suzuka Circuit                 Suzuka
# 38                Las Vegas Strip Street Circuit              Las Vegas
# 39                 Autódromo Juan y Oscar Gálvez           Buenos Aires
# 40                             Circuito de Jerez   Jerez de la Frontera
# 41                          Autódromo do Estoril                Estoril
# 42                 Okayama International Circuit                Okayama
# 43                       Adelaide Street Circuit               Adelaide
# 44                                       Kyalami                Midrand
# 45                                Donington Park       Castle Donington
# 46                        Phoenix street circuit                Phoenix
# 47                  Korean International Circuit         Yeongam County
# 48         Autódromo Internacional Nelson Piquet         Rio de Janeiro
# 49                        Detroit Street Circuit                Detroit
# 50                                  Brands Hatch                   Kent
# 51                        Circuit Park Zandvoort              Zandvoort
# 52                                        Zolder         Heusden-Zolder
# 53                                 Dijon-Prenois                  Dijon
# 54                                     Fair Park                 Dallas
# 55                                    Long Beach             California
# 56                                        Jarama                 Madrid
# 57                                  Watkins Glen         New York State
# 58                          Scandinavian Raceway             Anderstorp
# 59                 Mosport International Raceway                Ontario
# 60                                      Montjuïc              Barcelona
# 61                              Nivelles-Baulers               Brussels
# 62                               Charade Circuit       Clermont-Ferrand
# 63                        Circuit Mont-Tremblant                 Quebec
# 64                             Rouen-Les-Essarts                  Rouen
# 65                                       Le Mans                Le Mans
# 66                                   Reims-Gueux                  Reims
# 67                         Prince George Circuit  Eastern Cape Province
# 68                                       Zeltweg                 Styria
# 69                                       Aintree              Liverpool
# 70                          Circuito da Boavista                 Oporto
# 71               Riverside International Raceway             California
# 72                                          AVUS                 Berlin
# 73                         Monsanto Park Circuit                 Lisbon
# 74                 Sebring International Raceway                Florida
# 75                                      Ain Diab             Casablanca
# 76                               Pescara Circuit                Pescara
# 77                            Circuit Bremgarten                   Bern
# 78                          Circuit de Pedralbes              Barcelona
# 79                   Buddh International Circuit          Uttar Pradesh
# 80                       Jeddah Corniche Circuit                 Jeddah
# 81                  Losail International Circuit              Al Daayen
#
#          lat         lng
# 0   45.50600  -73.525000
# 1  -37.84970  144.968000
# 2   47.22300   14.761000
# 3   52.07200   -1.017000
# 4   41.56900    2.261000
# 5   50.43600    5.971000
# 6   45.62100    9.290000
# 7   43.40700   39.960000
# 8   50.33400    6.943000
# 9   37.23200   -8.628000
# 10  43.99800   11.372000
# 11  26.03100   50.512000
# 12  44.34300   11.716000
# 13  43.73500    7.421000
# 14  40.37200   49.853000
# 15  43.25100    5.793000
# 16  47.58100   19.250000
# 17  52.38900    4.541000
# 18  21.02100  105.843000
# 19  30.13300  -97.641000
# 20  19.40600  -99.090000
# 21  21.52700   39.187000
# 22  24.47000   54.603000
# 23  36.16900 -115.136000
# 24  25.77800  -80.202000
# 25 -37.84970  144.968000
# 26   2.76083  101.738000
# 27  40.95170   29.405000
# 28  46.86420    3.163610
# 29  49.32780    8.565830
# 30  39.45890   -0.331667
# 31   1.29140  103.864000
# 32  35.37170  138.927000
# 33  31.33890  121.220000
# 34 -23.70360  -46.699700
# 35  39.79500  -86.234700
# 37  34.84310  136.541000
# 38  36.11470 -115.173000
# 39 -34.69430  -58.459300
# 40  36.70830   -6.034170
# 41  38.75060   -9.394170
# 42  34.91500  134.221000
# 43 -34.92720  138.617000
# 44 -25.98940   28.076700
# 45  52.83060   -1.375280
# 46  33.44790 -112.075000
# 47  34.73330  126.417000
# 48 -22.97560  -43.395000
# 49  42.32980  -83.040100
# 50  51.35690    0.263056
# 51  52.38880    4.540920
# 52  50.98940    5.256940
# 53  47.36250    4.899130
# 54  32.77740  -96.758700
# 55  33.76510 -118.189000
# 56  40.61710   -3.585580
# 57  42.33690  -76.927200
# 58  57.26530   13.604200
# 59  44.04810  -78.675600
# 60  41.36640    2.151670
# 61  50.62110    4.326940
# 62  45.74720    3.038890
# 63  46.18770  -74.609900
# 64  49.33060    1.004580
# 65  47.95000    0.224231
# 66  49.25420    3.930830
# 67 -33.04860   27.873600
# 68  47.20390   14.747800
# 69  53.47690   -2.940560
# 70  41.17050   -8.673250
# 71  33.93700 -117.273000
# 72  52.48060   13.251400
# 73  38.71970   -9.203060
# 74  27.45470  -81.348300
# 75  33.57860   -7.687500
# 76  42.47500   14.150800
# 77  46.95890    7.401940
# 78  41.39030    2.116670
# 79  28.34870   77.533100
# 80  21.63190   39.104400
# 81  25.49000   51.454200
